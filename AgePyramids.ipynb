# %%
# Importing libraries
import pandas as pd
import plotly.graph_objects as go

# %%
pwd
# Out:
# 'C:\\Users\\RišoPC\\OneDrive\\Desktop\\COURSES\\Python\\UDEMY_TSA_FINAL\\Thesis\\Final'

# %%
# Importing data
data = pd.read_excel('AgePyramidData.xlsx')
display(data)
# Out:
#               Age  2020-Male  2020-Female     2025-Male   2025-Female  \
# 0               0    29365.0      28121.5  26168.000000  24681.000000
# 1               1    30199.0      28680.5  26854.812648  25330.492879
# 2               2    30647.5      29015.0  27560.375587  25999.671047
# 3               3    30634.5      29187.0  28272.009689  26666.865332
# 4               4    30135.5      28569.5  28973.355486  27328.312695
# 5               5    29405.5      27946.0  29650.514877  27969.616034
# 6               6    28970.0      27757.5  30038.993959  28087.658869
# 7               7    29159.0      27596.0  30494.483027  28931.315366
# 8               8    30452.0      28855.0  30329.676395  28990.708980
# 9               9    30471.5      29415.5  29629.003780  27827.777496
# 10             10    30147.0      28844.5  28917.697689  27788.486267
# 11             11    30051.5      28353.0  28816.847791  27503.653851
# ...

# %%
y_age = data['Age']
x_M = data['2020-Male']
x_F = data['2020-Female'] * -1

# %%
# Creating instance of the figure
fig = go.Figure()
  
# Adding Male data to the figure
fig.add_trace(go.Bar(y= y_age, x = x_M, 
                     name = 'Muži', 
                     orientation = 'h'))
  
# Adding Female data to the figure
fig.add_trace(go.Bar(y = y_age, x = x_F,
                     name = 'Ženy', orientation = 'h'))
  
# Updating the layout for our graph
fig.update_layout(title = 'Veková pyramída populácie SR v roku 2020',
                 barmode = 'relative',
                 bargap = 0.0, bargroupgap = 0,
                 xaxis = dict(tickvals = [-60000, -50000, -40000, -30000, -20000, -10000,
                                          0, 10000, 20000, 30000, 40000, 50000, 60000],
                                
                              ticktext = ['60K', '50K', '40K', '30K','20K', '10K', '0', 
                                          '10K', '20K', '30K', '40K', '50K', '60K'],
                                
                              title = 'Počet obyvateľov v tisícoch',
                              )
                 )
  
fig.show()
# Out:
# <div>                            <div id="0dc63353-1e00-40f2-9cb3-ef0f91b1f2be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dc63353-1e00-40f2-9cb3-ef0f91b1f2be")) {                    Plotly.newPlot(                        "0dc63353-1e00-40f2-9cb3-ef0f91b1f2be",                        [{"name":"Mu\u017ei","orientation":"h","x":[29365.0,30199.0,30647.5,30634.5,30135.5,29405.5,28970.0,29159.0,30452.0,30471.5,30147.0,30051.5,28586.5,27809.0,27869.0,27850.0,27080.5,26221.5,26299.0,27403.0,28322.5,28803.5,29623.0,30450.0,31035.0,32414.0,35372.5,37415.5,38482.5,39767.0,40057.5,40573.0,41351.5,42153.5,43611.5,44381.5,44519.5,44899.5,44939.0,45183.0,46571.5,47244.5,47109.0,47017.0,46104.0,45366.0,44027.0,41329.5,38850.5,37002.0,35951.0,34554.5,33615.5,
# ...

# %%
y_age = data['Age']
x_M = data['2025-Male']
x_F = data['2025-Female'] * -1

# %%
# Creating instance of the figure
fig = go.Figure()
  
# Adding Male data to the figure
fig.add_trace(go.Bar(y= y_age, x = x_M, 
                     name = 'Muži', 
                     orientation = 'h'))
  
# Adding Female data to the figure
fig.add_trace(go.Bar(y = y_age, x = x_F,
                     name = 'Ženy', orientation = 'h'))
  
# Updating the layout for our graph
fig.update_layout(title = 'Veková pyramída populácie SR v roku 2025',
                  barmode = 'relative',
                 bargap = 0.0, bargroupgap = 0,
                 xaxis = dict(tickvals = [-60000, -50000, -40000, -30000, -20000, -10000,
                                          0, 10000, 20000, 30000, 40000, 50000, 60000],
                                
                              ticktext = ['60K', '50K', '40K', '30K','20K', '10K', '0', 
                                          '10K', '20K', '30K', '40K', '50K', '60K'],
                                
                              title = 'Počet obyvateľov v tisícoch',
                              )
                 )
  
fig.show()
# Out:
# <div>                            <div id="10058c1a-9475-4a69-8e0b-9687a8c5a117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10058c1a-9475-4a69-8e0b-9687a8c5a117")) {                    Plotly.newPlot(                        "10058c1a-9475-4a69-8e0b-9687a8c5a117",                        [{"name":"Mu\u017ei","orientation":"h","x":[26168.0,26854.812647537987,27560.375587198043,28272.0096888619,28973.35548633164,29650.514876610305,30038.993959122705,30494.483026683727,30329.67639528499,29629.003779813724,28917.697689021654,28816.847790718242,29363.217030907763,31413.29273470354,29422.440876232744,30815.43054039809,29237.794464707902,27881.006748082436,27666.779918002194,27972.38818618066,27607.775470218236,26425.23165553357,25876.668036427218,26517.
# ...

# %%
y_age = data['Age']
x_M = data['2030-Male']
x_F = data['2030-Female'] * -1

# %%
# Creating instance of the figure
fig = go.Figure()
  
# Adding Male data to the figure
fig.add_trace(go.Bar(y= y_age, x = x_M, 
                     name = 'Muži', 
                     orientation = 'h'))
  
# Adding Female data to the figure
fig.add_trace(go.Bar(y = y_age, x = x_F,
                     name = 'Ženy', orientation = 'h'))
  
# Updating the layout for our graph
fig.update_layout(title = 'Veková pyramída populácie SR v roku 2030',
                 barmode = 'relative',
                 bargap = 0.0, bargroupgap = 0,
                 xaxis = dict(tickvals = [-60000, -50000, -40000, -30000, -20000, -10000,
                                          0, 10000, 20000, 30000, 40000, 50000, 60000],
                                
                              ticktext = ['60K', '50K', '40K', '30K','20K', '10K', '0', 
                                          '10K', '20K', '30K', '40K', '50K', '60K'],
                                
                              title = 'Počet obyvateľov v tisícoch',
                              )
                 )
  
fig.show()
# Out:
# <div>                            <div id="ee75fbfe-9f4b-434e-a32d-2d415600e766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee75fbfe-9f4b-434e-a32d-2d415600e766")) {                    Plotly.newPlot(                        "ee75fbfe-9f4b-434e-a32d-2d415600e766",                        [{"name":"Mu\u017ei","orientation":"h","x":[23316.0,23760.562556105997,24274.311592045084,24844.52425575052,25467.30578085608,26135.839703949146,26836.046403618282,27545.455919269745,28257.73290187983,28957.721680499475,29632.784707988805,30015.91999397842,30471.877602785342,30306.80418468414,29603.287555462022,28889.97583155381,28783.174119492756,29327.460225117262,31364.296520780226,29366.15776689259,30737.245732257255,29159.70304297945,27785.08650317786,27562.5
# ...
